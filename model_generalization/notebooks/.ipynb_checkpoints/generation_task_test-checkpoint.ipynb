# %%
from transformers import pipeline, AutoTokenizer, AutoModelWithLMHead
# Out:
# I0514 10:33:02.466326 4520269248 file_utils.py:41] PyTorch version 1.0.1.post2 available.

# %%
from pprint import pprint

# %%
mask_dictionary = {
    "bert-base-uncased" : "[MASK]",
    "bert-base-cased" : "[MASK]",
    "bert-large-uncased": "[MASK]",
    "bert-large-cased" : "[MASK]",
    "roberta-base" : "<mask>",
    "roberta-large" : "<mask>"
}

# %%
context_file="../../examples/contexts/test.txt"
nonce_file="../../examples/nonce roots/test.txt"
model_name="bert-base-cased"
mask_whole_word = True
force_sentence=None

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelWithLMHead.from_pretrained(model_name)
# Out:
# I0514 10:37:14.126261 4520269248 filelock.py:274] Lock 4456545192 acquired on /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391.lock
# I0514 10:37:14.127954 4520269248 file_utils.py:479] https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-config.json not found in cache or force_download set to True, downloading to /Users/eva/.cache/torch/transformers/tmpjxwua8xt
# HBox(children=(IntProgress(value=0, description='Downloading', max=433, style=ProgressStyle(description_width=…
# I0514 10:37:14.505147 4520269248 file_utils.py:489] storing https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-config.json in cache at /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391
# I0514 10:37:14.506995 4520269248 file_utils.py:492] creating metadata file for /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391
# I0514 10:37:14.508530 4520269248 filelock.py:318] Lock 4456545192 released on /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391.lock
# I0514 10:37:14.509686 4520269248 configuration_utils.py:286] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-config.json from cache at /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391
# I0514 10:37:14.510682 4520269248 configuration_utils.py:322] Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
# I0514 10:37:14.862262 4520269248 tokenization_utils.py:979] loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-vocab.txt from cache at /Users/eva/.cache/torch/transformers/5e8a2b4893d13790ed4150ca1906be5f7a03d6c4ddf62296c383f6db42814db2.e13dbb970cb325137104fb2e5f36fe865f27746c6b526f6352861b1980eb80b1
# I0514 10:37:15.313812 4520269248 configuration_utils.py:286] loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-config.json from cache at /Users/eva/.cache/torch/transformers/b945b69218e98b3e2c95acf911789741307dec43c698d35fad11c1ae28bda352.9da767be51e1327499df13488672789394e2ca38b877837e52618a67d7002391
# I0514 10:37:15.315132 4520269248 configuration_utils.py:322] Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "type_vocab_size": 2,
#   "vocab_size": 28996
# }
#
# I0514 10:37:15.687870 4520269248 modeling_utils.py:612] loading weights file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-cased-pytorch_model.bin from cache at /Users/eva/.cache/torch/transformers/35d8b9d36faaf46728a0192d82bf7d00137490cd6074e8500778afed552a67e5.3fadbea36527ae472139fe84cddaa65454d7429f12d543d80bfc3ad70de55ac2
# I0514 10:37:20.234036 4520269248 modeling_utils.py:703] Weights of BertForMaskedLM not initialized from pretrained model: ['cls.predictions.decoder.bias']
# I0514 10:37:20.234754 4520269248 modeling_utils.py:709] Weights from pretrained model not used in BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']

# %%
fill_mask = pipeline(
    "fill-mask",
    model=model,
    tokenizer=tokenizer
)

# %%
def read_file(file_name):
    with open(file_name) as f:
        for line in f.readlines():
            l = line.strip()
            if len(l) < 1:
                continue
            yield l

def _get_data_set():
    dataset = []
    for context in read_file(context_file):
        for nonce in read_file(nonce_file):
            num_masks = context.count("YYY")
            if mask_whole_word:
                sample = context.replace("XXX", nonce).replace("YYY", mask_dictionary[model_name]).lstrip()
            else:
                sample = context.replace("XXX", nonce).replace("YYY", nonce+mask_dictionary[model_name]).lstrip()
            
            dataset.append((num_masks, sample))

    return dataset

# %%
def get_fills(datapoints):
    fills = []
    for datum in datapoints:
        filled = fill_mask(datum)
        fills.append(filled)
    return fills
    


def generation_task(dataset):
    for num_masks, sample in dataset:
        if num_masks == 2:
            split_int = sample.find(".", sample.find(mask_dictionary[model_name])) + 1
            first_filled = get_fills([sample[:split_int]])
            second_samples = []
            for datum in first_filled[0]:
                prev_fill = datum['sequence'][6:-6]
                second_samples.append(prev_fill+sample[split_int:])
            filled = get_fills(second_samples)
            pprint(filled)

        elif num_masks == 1: 
            filled = get_fills([sample])
            pprint(filled)

# %%
dataset = _get_data_set()

# %%
dataset
# Out:
# [(1,
#   'This is a akar. Now there is another one. There are two of them. There are two [MASK].'),
#  (1,
#   'This is a bem. Now there is another one. There are two of them. There are two [MASK].'),
#  (1,
#   'This is a bink. Now there is another one. There are two of them. There are two [MASK].'),
#  (1,
#   'My favorite animal is the akar. They are impressive creatures. I saw a group of [MASK] during our trip last summer and I was so excited.'),
#  (1,
#   'My favorite animal is the bem. They are impressive creatures. I saw a group of [MASK] during our trip last summer and I was so excited.'),
#  (1,
#   'My favorite animal is the bink. They are impressive creatures. I saw a group of [MASK] during our trip last summer and I was so excited.'),
#  (2,
#   'Here is a akar thing. Here are two other things that are akar. This one is the [MASK] of them all. It is [MASK] than the rest.'),
#  (2,
#   'Here is a bem thing. Here are two other things that are bem. This one is the [MASK] of them all. It is [MASK] than the rest.'),
#  (2,
#   'Here is a bink thing. Here are two other things that are bink. This one is the [MASK] of them all. It is [MASK] than the rest.'),
#  (2,
#   "My mom's food always tastes akar. She learnt to cook akar food from her mom. I think she makes the [MASK] food in the world. Or at least, [MASK] food than my dad does."),
#  (2,
#   "My mom's food always tastes bem. She learnt to cook bem food from her mom. I think she makes the [MASK] food in the world. Or at least, [MASK] food than my dad does."),
#  (2,
#   "My mom's food always tastes bink. She learnt to cook bink food from her mom. I think she makes the [MASK] food in the world. Or at least, [MASK] food than my dad does."),
#  (2,
#   "You should akar. It's always worthwhile to akar. I'm [MASK], and you should too. Last week you [MASK], why won't you now?"),
#  (2,
#   "You should bem. It's always worthwhile to bem. I'm [MASK], and you should too. Last week you [MASK], why won't you now?"),
#  (2,
#   "You should bink. It's always worthwhile to bink. I'm [MASK], and you should too. Last week you [MASK], why won't you now?"),
#  (2,
#   "I dream that one day I'll be able to akar. The chance to akar would be very exciting. I think I'd really enjoy [MASK]. My friend Sam [MASK] once and he loved it."),
#  (2,
#   "I dream that one day I'll be able to bem. The chance to bem would be very exciting. I think I'd really enjoy [MASK]. My friend Sam [MASK] once and he loved it."),
#  (2,
#   "I dream that one day I'll be able to bink. The chance to bink would be very exciting. I think I'd really enjoy [MASK]. My friend Sam [MASK] once and he loved it.")]

# %%
generation_task(dataset)
# Out:
# [[{'score': 0.24029260873794556,
#    'sequence': '[CLS] This is a akar. Now there is another one. There are two '
#                'of them. There are two more. [SEP]',
#    'token': 1167},
#   {'score': 0.08045287430286407,
#    'sequence': '[CLS] This is a akar. Now there is another one. There are two '
#                'of them. There are two others. [SEP]',
#    'token': 1639},
#   {'score': 0.014251087792217731,
#    'sequence': '[CLS] This is a akar. Now there is another one. There are two '
#                'of them. There are two things. [SEP]',
#    'token': 1614},
#   {'score': 0.012425841763615608,
#    'sequence': '[CLS] This is a akar. Now there is another one. There are two '
#                'of them. There are two people. [SEP]',
#    'token': 1234},
#   {'score': 0.011075000278651714,
#    'sequence': '[CLS] This is a akar. Now there is another one. There are two '
#                'of them. There are two doors. [SEP]',
#    'token': 3581}]]
# [[{'score': 0.16099847853183746,
#    'sequence': '[CLS] This is a bem. Now there is another one. There are two '
#                'of them. There are two more. [SEP]',
#    'token': 1167},
#   {'score': 0.09590600430965424,
#    'sequence': '[CLS] This is a bem. Now there is another one. There are two '
#                'of them. There are two others. [SEP]',
#    'token': 1639},
#   {'score': 0.024217519909143448,
#    'sequence': '[CLS] This is a bem. Now there is another one. There are two '
#                'of them. There are two things. [SEP]',
#    'token': 1614},
#   {'score': 0.01800924353301525,
#    'sequence': '[CLS] This is a bem. Now there is another one. There are two '
#                'of them. There are two people. [SEP]',
#    'token': 1234},
#   {'score': 0.01625881902873516,
#    'sequence': '[CLS] This is a bem. Now there is another one. There are two '
#                'of them. There are two men. [SEP]',
#    'token': 1441}]]
# [[{'score': 0.20800139009952545,
#    'sequence': '[CLS] This is a bink. Now there is another one. There are two '
#                'of them. There are two more. [SEP]',
#    'token': 1167},
#   {'score': 0.08181122690439224,
#    'sequence': '[CLS] This is a bink. Now there is another one. There are two '
#                'of them. There are two others. [SEP]',
#    'token': 1639},
#   {'score': 0.017581554129719734,
#    'sequence': '[CLS] This is a bink. Now there is another one. There are two '
#                'of them. There are two things. [SEP]',
#    'token': 1614},
#   {'score': 0.014324842020869255,
#    'sequence': '[CLS] This is a bink. Now there is another one. There are two '
#                'of them. There are two people. [SEP]',
#    'token': 1234},
#   {'score': 0.012030656449496746,
#    'sequence': '[CLS] This is a bink. Now there is another one. There are two '
#                'of them. There are two worlds. [SEP]',
#    'token': 11308}]]
# [[{'score': 0.7160810232162476,
#    'sequence': '[CLS] My favorite animal is the akar. They are impressive '
#                'creatures. I saw a group of them during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1172},
#   {'score': 0.029577992856502533,
#    'sequence': '[CLS] My favorite animal is the akar. They are impressive '
#                'creatures. I saw a group of us during our trip last summer and '
#                'I was so excited. [SEP]',
#    'token': 1366},
#   {'score': 0.02322402596473694,
#    'sequence': '[CLS] My favorite animal is the akar. They are impressive '
#                'creatures. I saw a group of people during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1234},
#   {'score': 0.015396148897707462,
#    'sequence': '[CLS] My favorite animal is the akar. They are impressive '
#                'creatures. I saw a group of guys during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 3713},
#   {'score': 0.015343103557825089,
#    'sequence': '[CLS] My favorite animal is the akar. They are impressive '
#                'creatures. I saw a group of animals during our trip last '
#                'summer and I was so excited. [SEP]',
#    'token': 3551}]]
# [[{'score': 0.6763458847999573,
#    'sequence': '[CLS] My favorite animal is the bem. They are impressive '
#                'creatures. I saw a group of them during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1172},
#   {'score': 0.03038514405488968,
#    'sequence': '[CLS] My favorite animal is the bem. They are impressive '
#                'creatures. I saw a group of people during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1234},
#   {'score': 0.026033425703644753,
#    'sequence': '[CLS] My favorite animal is the bem. They are impressive '
#                'creatures. I saw a group of us during our trip last summer and '
#                'I was so excited. [SEP]',
#    'token': 1366},
#   {'score': 0.020229078829288483,
#    'sequence': '[CLS] My favorite animal is the bem. They are impressive '
#                'creatures. I saw a group of animals during our trip last '
#                'summer and I was so excited. [SEP]',
#    'token': 3551},
#   {'score': 0.016263281926512718,
#    'sequence': '[CLS] My favorite animal is the bem. They are impressive '
#                'creatures. I saw a group of birds during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 4939}]]
# [[{'score': 0.6446279883384705,
#    'sequence': '[CLS] My favorite animal is the bink. They are impressive '
#                'creatures. I saw a group of them during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1172},
#   {'score': 0.03423447906970978,
#    'sequence': '[CLS] My favorite animal is the bink. They are impressive '
#                'creatures. I saw a group of people during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 1234},
#   {'score': 0.029935715720057487,
#    'sequence': '[CLS] My favorite animal is the bink. They are impressive '
#                'creatures. I saw a group of us during our trip last summer and '
#                'I was so excited. [SEP]',
#    'token': 1366},
#   {'score': 0.020109929144382477,
#    'sequence': '[CLS] My favorite animal is the bink. They are impressive '
#                'creatures. I saw a group of kids during our trip last summer '
#                'and I was so excited. [SEP]',
#    'token': 4067},
#   {'score': 0.01872514747083187,
#    'sequence': '[CLS] My favorite animal is the bink. They are impressive '
#                'creatures. I saw a group of animals during our trip last '
#                'summer and I was so excited. [SEP]',
#    'token': 3551}]]
# [[{'score': 0.8619868755340576,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the worst of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.09241875261068344,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the worst of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.009849663823843002,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the worst of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.009118619374930859,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the worst of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.0038932163733989,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the worst of them all. It is weaker than the '
#                'rest. [SEP]',
#    'token': 16990}],
#  [{'score': 0.7995626926422119,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the best of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.0578799843788147,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the best of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.045956265181303024,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the best of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.02473876066505909,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the best of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.008453800342977047,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the best of them all. It is faster than the '
#                'rest. [SEP]',
#    'token': 4946}],
#  [{'score': 0.5746026635169983,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the biggest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.15232279896736145,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the biggest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.12682701647281647,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the biggest of them all. It is larger than '
#                'the rest. [SEP]',
#    'token': 2610},
#   {'score': 0.026787370443344116,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the biggest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.026069875806570053,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the biggest of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992}],
#  [{'score': 0.28452837467193604,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the simplest of them all. It is simpler than '
#                'the rest. [SEP]',
#    'token': 17633},
#   {'score': 0.17770792543888092,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the simplest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.05931485816836357,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the simplest of them all. It is stronger '
#                'than the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.05533817037940025,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the simplest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.052430011332035065,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the simplest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706}],
#  [{'score': 0.29483744502067566,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the greatest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.15538427233695984,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the greatest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.11617839336395264,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the greatest of them all. It is stronger '
#                'than the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.11168420314788818,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the greatest of them all. It is worse than '
#                'the rest. [SEP]',
#    'token': 4146},
#   {'score': 0.09238720685243607,
#    'sequence': '[CLS] Here is a akar thing. Here are two other things that are '
#                'akar. This one is the greatest of them all. It is greater than '
#                'the rest. [SEP]',
#    'token': 3407}]]
# [[{'score': 0.835053026676178,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the best of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.05372175946831703,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the best of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.03767198696732521,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the best of them all. It is stronger than the '
#                'rest. [SEP]',
#    'token': 5992},
#   {'score': 0.019669361412525177,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the best of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.005209511145949364,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the best of them all. It is faster than the '
#                'rest. [SEP]',
#    'token': 4946}],
#  [{'score': 0.8873281478881836,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the worst of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.07629644870758057,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the worst of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.009180355817079544,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the worst of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.005484758876264095,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the worst of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.002693796996027231,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the worst of them all. It is weaker than the '
#                'rest. [SEP]',
#    'token': 16990}],
#  [{'score': 0.6600787043571472,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the biggest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.12944208085536957,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the biggest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.10524871200323105,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the biggest of them all. It is larger than '
#                'the rest. [SEP]',
#    'token': 2610},
#   {'score': 0.019740598276257515,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the biggest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.014738105237483978,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the biggest of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992}],
#  [{'score': 0.4805961549282074,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the smallest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.2224220633506775,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the smallest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.19263164699077606,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the smallest of them all. It is larger than '
#                'the rest. [SEP]',
#    'token': 2610},
#   {'score': 0.009688247926533222,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the smallest of them all. It is shorter than '
#                'the rest. [SEP]',
#    'token': 7681},
#   {'score': 0.009538563899695873,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the smallest of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992}],
#  [{'score': 0.35717543959617615,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the simplest of them all. It is simpler than '
#                'the rest. [SEP]',
#    'token': 17633},
#   {'score': 0.15343241393566132,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the simplest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.05666382238268852,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the simplest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.05341099947690964,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the simplest of them all. It is worse than '
#                'the rest. [SEP]',
#    'token': 4146},
#   {'score': 0.05261433869600296,
#    'sequence': '[CLS] Here is a bem thing. Here are two other things that are '
#                'bem. This one is the simplest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706}]]
# [[{'score': 0.8642948269844055,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the worst of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.09021330624818802,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the worst of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.012807443737983704,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the worst of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.0061659361235797405,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the worst of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.002968849614262581,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the worst of them all. It is weaker than the '
#                'rest. [SEP]',
#    'token': 16990}],
#  [{'score': 0.8331902027130127,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the best of them all. It is better than the '
#                'rest. [SEP]',
#    'token': 1618},
#   {'score': 0.04621179401874542,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the best of them all. It is worse than the '
#                'rest. [SEP]',
#    'token': 4146},
#   {'score': 0.03424707055091858,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the best of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992},
#   {'score': 0.02554612047970295,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the best of them all. It is bigger than the '
#                'rest. [SEP]',
#    'token': 6706},
#   {'score': 0.006639262195676565,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the best of them all. It is faster than the '
#                'rest. [SEP]',
#    'token': 4946}],
#  [{'score': 0.6321719288825989,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the biggest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.13647472858428955,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the biggest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.11043652892112732,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the biggest of them all. It is larger than '
#                'the rest. [SEP]',
#    'token': 2610},
#   {'score': 0.024519775062799454,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the biggest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.015087522566318512,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the biggest of them all. It is stronger than '
#                'the rest. [SEP]',
#    'token': 5992}],
#  [{'score': 0.4457074999809265,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the smallest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.2544364631175995,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the smallest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.1892445832490921,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the smallest of them all. It is larger than '
#                'the rest. [SEP]',
#    'token': 2610},
#   {'score': 0.010573933832347393,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the smallest of them all. It is heavier than '
#                'the rest. [SEP]',
#    'token': 12163},
#   {'score': 0.010108605027198792,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the smallest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618}],
#  [{'score': 0.33395257592201233,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the simplest of them all. It is simpler than '
#                'the rest. [SEP]',
#    'token': 17633},
#   {'score': 0.1564428210258484,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the simplest of them all. It is better than '
#                'the rest. [SEP]',
#    'token': 1618},
#   {'score': 0.06546270102262497,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the simplest of them all. It is bigger than '
#                'the rest. [SEP]',
#    'token': 6706},
#   {'score': 0.06317552924156189,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the simplest of them all. It is smaller than '
#                'the rest. [SEP]',
#    'token': 2964},
#   {'score': 0.04476553201675415,
#    'sequence': '[CLS] Here is a bink thing. Here are two other things that are '
#                'bink. This one is the simplest of them all. It is worse than '
#                'the rest. [SEP]',
#    'token': 4146}]]
# [[{'score': 0.6708910465240479,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the best food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.2876175045967102,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the best food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.011047733947634697,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the best food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.005384471733123064,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the best food in the '
#                'world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.004762391094118357,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the best food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.686080813407898,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the finest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.2642424702644348,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the finest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.009374911896884441,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the finest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.0060579050332307816,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the finest food in '
#                'the world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.005764748435467482,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the finest food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.4494372606277466,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the worst food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146},
#   {'score': 0.4019971489906311,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the worst food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.07158604264259338,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the worst food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.044418271631002426,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the worst food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.004332037642598152,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the worst food in '
#                'the world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992}],
#  [{'score': 0.57894366979599,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.19259393215179443,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.1591038703918457,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.02098166011273861,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.008954267017543316,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.6478654146194458,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.2907930314540863,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.01147468388080597,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.011185871437191963,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146},
#   {'score': 0.009917005896568298,
#    'sequence': "[CLS] My mom's food always tastes akar. She learnt to cook "
#                'akar food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750}]]
# [[{'score': 0.6046616435050964,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the best food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.3523208498954773,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the best food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.014561043120920658,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the best food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.004836780950427055,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the best food in the '
#                'world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.00447944225743413,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the best food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.6117993593215942,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the finest food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.3364972174167633,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the finest food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.013107625767588615,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the finest food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.005686814431101084,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the finest food in the '
#                'world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.005615626461803913,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the finest food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.44226229190826416,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the worst food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146},
#   {'score': 0.36223506927490234,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the worst food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.09854944795370102,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the worst food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.06325078755617142,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the worst food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.004447394981980324,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the worst food in the '
#                'world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992}],
#  [{'score': 0.6429215669631958,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the biggest food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.17076276242733002,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the biggest food in the '
#                'world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.12176811695098877,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the biggest food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.025031810626387596,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the biggest food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.007038105744868517,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the biggest food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}],
#  [{'score': 0.5798365473747253,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the greatest food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.35647958517074585,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the greatest food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.012923701666295528,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the greatest food in the '
#                'world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.012090745382010937,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the greatest food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.009921323508024216,
#    'sequence': "[CLS] My mom's food always tastes bem. She learnt to cook bem "
#                'food from her mom. I think she makes the greatest food in the '
#                'world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}]]
# [[{'score': 0.5996712446212769,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the best food in the '
#                'world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.351339727640152,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the best food in the '
#                'world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.015843093395233154,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the best food in the '
#                'world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.00572161702439189,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the best food in the '
#                'world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.004036481957882643,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the best food in the '
#                'world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706}],
#  [{'score': 0.6118037104606628,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the finest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.3292504847049713,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the finest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.013963744044303894,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the finest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.006566337309777737,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the finest food in '
#                'the world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992},
#   {'score': 0.005596233066171408,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the finest food in '
#                'the world. Or at least, cheaper food than my dad does. [SEP]',
#    'token': 17780}],
#  [{'score': 0.41363972425460815,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the worst food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146},
#   {'score': 0.3859313130378723,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the worst food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.09518523514270782,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the worst food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.06406598538160324,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the worst food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.005544715560972691,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the worst food in '
#                'the world. Or at least, stronger food than my dad does. [SEP]',
#    'token': 5992}],
#  [{'score': 0.6203254461288452,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.17718669772148132,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.12988649308681488,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.026179641485214233,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.006785986479371786,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the biggest food in '
#                'the world. Or at least, larger food than my dad does. [SEP]',
#    'token': 2610}],
#  [{'score': 0.5887745022773743,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, better food than my dad does. [SEP]',
#    'token': 1618},
#   {'score': 0.3432169556617737,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, more food than my dad does. [SEP]',
#    'token': 1167},
#   {'score': 0.013191577047109604,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, bigger food than my dad does. [SEP]',
#    'token': 6706},
#   {'score': 0.012567926198244095,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, less food than my dad does. [SEP]',
#    'token': 1750},
#   {'score': 0.009408382698893547,
#    'sequence': "[CLS] My mom's food always tastes bink. She learnt to cook "
#                'bink food from her mom. I think she makes the greatest food in '
#                'the world. Or at least, worse food than my dad does. [SEP]',
#    'token': 4146}]]
# [[{'score': 0.24049748480319977,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "sorry, and you should too. Last week you said, why won't you "
#                'now? [SEP]',
#    'token': 1163},
#   {'score': 0.09002809971570969,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "sorry, and you should too. Last week you left, why won't you "
#                'now? [SEP]',
#    'token': 1286},
#   {'score': 0.05376110225915909,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "sorry, and you should too. Last week you thought, why won't "
#                'you now? [SEP]',
#    'token': 1354},
#   {'score': 0.03388866409659386,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "sorry, and you should too. Last week you called, why won't you "
#                'now? [SEP]',
#    'token': 1270},
#   {'score': 0.02506070025265217,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "sorry, and you should too. Last week you died, why won't you "
#                'now? [SEP]',
#    'token': 1452}],
#  [{'score': 0.17497530579566956,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
#                "here, and you should too. Last week you said, why won't you "
#                'now? [SEP]',
#    'token': 1163},
#   {'score': 0.11997798830270767,
#    'sequence': "[CLS] You should akar. It's always worthwhile to akar. I'm "
# ...
#                "akar would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.04647905007004738,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.03849168121814728,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348}],
#  [{'score': 0.14001452922821045,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.13912035524845123,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.08982302248477936,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.053562577813863754,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348},
#   {'score': 0.03958646580576897,
#    'sequence': "[CLS] I dream that one day I'll be able to akar. The chance to "
#                "akar would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam tried once and he loved it. [SEP]',
#    'token': 1793}]]
# [[{'score': 0.19118307530879974,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.14848457276821136,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.08910056203603745,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.03308642655611038,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam was once and he loved it. [SEP]',
#    'token': 1108},
#   {'score': 0.031973764300346375,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam tried once and he loved it. [SEP]',
#    'token': 1793}],
#  [{'score': 0.19499428570270538,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.11595924198627472,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.10482549667358398,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.030443156138062477,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348},
#   {'score': 0.029943635687232018,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam tried once and he loved it. [SEP]',
#    'token': 1793}],
#  [{'score': 0.18041810393333435,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.1205744668841362,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.11293517798185349,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.032677989453077316,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam was once and he loved it. [SEP]',
#    'token': 1108},
#   {'score': 0.03186124190688133,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348}],
#  [{'score': 0.17390310764312744,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.12752419710159302,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.12281451374292374,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.03841457515954971,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348},
#   {'score': 0.02892770990729332,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam was once and he loved it. [SEP]',
#    'token': 1108}],
#  [{'score': 0.15147115290164948,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.12072131037712097,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.11494144052267075,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.050303637981414795,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348},
#   {'score': 0.03702442720532417,
#    'sequence': "[CLS] I dream that one day I'll be able to bem. The chance to "
#                "bem would be very exciting. I think I'd really enjoy you. My "
#                'friend Sam said once and he loved it. [SEP]',
#    'token': 1163}]]
# [[{'score': 0.1389194279909134,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.12119679898023605,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.11344470828771591,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.07552226632833481,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.044467974454164505,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy it. My "
#                'friend Sam did once and he loved it. [SEP]',
#    'token': 1225}],
#  [{'score': 0.14432871341705322,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.11900767683982849,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.09170373529195786,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.08963573724031448,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.0436880923807621,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy that. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348}],
#  [{'score': 0.15770024061203003,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.11347267776727676,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.09625507891178131,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.08039660006761551,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.045965660363435745,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy this. My "
#                'friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348}],
#  [{'score': 0.16502512991428375,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.10857264697551727,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.10075496137142181,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.07067874819040298,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.054302606731653214,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy myself. "
#                'My friend Sam laughed once and he loved it. [SEP]',
#    'token': 3348}],
#  [{'score': 0.19132760167121887,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy going. "
#                'My friend Sam visited once and he loved it. [SEP]',
#    'token': 3891},
#   {'score': 0.10371534526348114,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy going. "
#                'My friend Sam played once and he loved it. [SEP]',
#    'token': 1307},
#   {'score': 0.0957404226064682,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy going. "
#                'My friend Sam died once and he loved it. [SEP]',
#    'token': 1452},
#   {'score': 0.07656911015510559,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy going. "
#                'My friend Sam won once and he loved it. [SEP]',
#    'token': 1281},
#   {'score': 0.04288044944405556,
#    'sequence': "[CLS] I dream that one day I'll be able to bink. The chance to "
#                "bink would be very exciting. I think I'd really enjoy going. "
#                'My friend Sam tried once and he loved it. [SEP]',
#    'token': 1793}]]

# %%
def read_file_with_meta(file_name):
    with open(file_name) as f:
        for line in f.readlines():
            item_type = 
            l = line.strip()
            if len(l) < 1:
                continue
            yield item_type,l


def _get_data_set_with_meta():
    dataset = []
    for category,context in read_file(context_file):
        for item,root in read_file_with_meta(nonce_file):
            num_masks = context.count("YYY")
            if mask_whole_word:
                prompt = context.replace("XXX", root).replace("YYY", mask_dictionary[model_name]).lstrip()
            else:
                prompt = context.replace("XXX", root).replace("YYY", root+mask_dictionary[model_name]).lstrip()
            
            dataset.append((num_masks, prompt, context, root, item, category))

    return dataset




def generation_task(dataset):
    results = []
    for (num_masks, prompt, context, root, item, category) in dataset:
        if num_masks == 2:
            split_int = prompt.find(".", prompt.find(mask_dictionary[model_name])) + 1
            first_filled = get_fills([prompt[:split_int]])
            second_prompts = []
            for datum in first_filled[0]:
                prev_fill = datum['sequence'][6:-6]
                second_prompts.append(prev_fill+prompt[split_int:])
            response = get_fills(second_prompts)
            results.append((num_masks, prompt, context, root, item, category, response))

        elif num_masks == 1: 
            response = get_fills([sample])
            results.append((num_masks, prompt, context, root, item, category, response))
